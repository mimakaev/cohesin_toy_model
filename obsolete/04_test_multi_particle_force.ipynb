# %%
from polychrom.hdf5_format import HDF5Reporter
from polychrom.polymerutils import fetch_block
from polychrom import forcekits, forces, starting_conformations, simulation
from polychrom.hdf5_format import HDF5Reporter
import numpy as np
import openmm as mm
from dataclasses import dataclass, field
from math import pi
import pickle 
import math
from typing import Dict, List, Tuple, TypedDict, Any, Sequence

import numpy as np


from poly_shared import (
    MoleculeStructure,
    Bond,
    Angle,
    Dihedral,
    dihedral_angle,
    verify_bond_angle_dihedral_uniqeness,
    concatenate_molecule_structures,
    build_ribbon,
    connect_ribbon_ends,
    connect_with_polymer,
    add_polymer_forces,
)

# %%
r = 15.0
# monomer count around ring ≈ circumference/step
n_ring = int(2*math.pi*r/0.9)
ring = build_hairy_ring(r, n_ring, p_hairy=0.1, seed=42, start_particle_index=0)
ring_s = ring.start_particle_index
ring_e = ring.get_end_idx()


# attach two lines length=20 at roughly opposite points
half = n_ring//2
idxA = ring.index_dict[(0,0)]
idxB = ring.index_dict[(half,0)]


l1s, l1e = attach_line(ring, attach_idx=idxA, n_monomers=25, seed=1)
l2s, l2e = attach_line(ring, attach_idx=idxB, n_monomers=25, seed=2)

# %%
from openmm import CustomManyParticleForce

force_eq = """
r = (
r12 = distance(p1, p2); r13 = distance(p1, p3); r23 = distance(p2, p3)
"""


# CustomManyParticleForce* force = new CustomManyParticleForce(3,
#      "L*eps*(cos(theta1)+1/3)^2*exp(sigma*gamma/(r12-a*sigma))*exp(sigma*gamma/(r13-a*sigma));"
#        "r12 = distance(p1,p2); r13 = distance(p1,p3); theta1 = angle(p3,p1,p2)");
#  force->setPermutationMode(CustomManyParticleForce::UniqueCentralParticle);

# %%
# combined_structure = concatenate_molecule_structures(
#     [ring],
#     extra_bonds=[],
#     extra_angles=[],
#     extra_dihedrals=[],
# )


# manually construct molecular structure for a length=10 line in the X,Y,Z direction from (1,0,0), etc.
index = 0 
lines = []
for dim in range(3):

    pos = np.zeros((40, 3), float)
    bonds = []
    angles = []
    for i in range(40):
        pos[i, dim] = 0.7 + i * 0.85  # X direction, 0.9 is the step size
        if i > 0:
            bonds.append((i+index - 1, i+index, 1, 0.05))
        if i > 1:
            angles.append((i+index - 2, i+index - 1, i+index, math.pi, 2.))
    dummmyIndexDict = {(0,i):i + index for i in range(40)}
    line1 = MoleculeStructure(
        n_rows=1,
        start_particle_index=index,
        positions=pos,
        bonds=bonds,
        angles=angles,
        dihedrals=[],
        index_dict=dummmyIndexDict,
    )
    index += 40
    lines.append(line1)

combined_structure = concatenate_molecule_structures(
    lines)





N = len(combined_structure.positions)
positions = combined_structure.positions.copy()
bonds = combined_structure.bonds.copy()
angles = combined_structure.angles.copy()
dihedrals = combined_structure.dihedrals.copy()


positions = pickle.load(open("spider.pkl", "rb"))

reporter = HDF5Reporter(folder="trajectory", max_data_length=5, overwrite=True)
sim = simulation.Simulation(
    platform="OpenCL",
    integrator="variableLangevin",
    error_tol=0.001,
    GPU="0",
    collision_rate=0.02,
    N=N,
    save_decimals=2,
    PBCbox=False,
    reporters=[reporter],
)


sim.set_data(positions, center=True)  # loads a polymer, puts a center of mass at zero
# Add forces to the simulation
res = add_polymer_forces(sim, bonds, angles, dihedrals)

# sim.add_force(forces.spherical_confinement(sim, r=5, k=1))
# nonbonded force
rep_force = forces.polynomial_repulsive(sim, trunc=50)
sim.add_force(rep_force)

type1_indices = list(range(40)) # entire first chain vs start of chain 2,3
type2_indices = [40,41]
type3_indices = [80,81]

three_way_force = threeWayAttraction(
    sim,
    type1_particle_idx=type1_indices,
    type2_particle_idx=type2_indices,
    type3_particle_idx=type3_indices,
    attractionEnergy=2.2,
    attractionRadius=2.0,
)
sim.add_force(three_way_force)


remover = mm.CMMotionRemover()
remover.name = "remover"  # type: ignore - this is polychrom's old convention
sim.add_force(remover)  # add motion remover to remove center of mass motion

sim.eK_critical = 1000

sim.local_energy_minimization()
#sim.local_energy_minimization()
#sim.local_energy_minimization()

all_dh = []
for block in range(100):
    sim.do_block(
        1 if block == 0 else 2000, save_extras={"bonds": bonds}
    )  # Of 100 timesteps each. Data is saved automatically.
    pos = sim.get_data()


sim.print_stats()  # In the end, print very simple statistics

reporter.dump_data()  # always need to run in the end to dump the block cache to the disk
# Out:
# INFO:root:Performing local energy minimization
# INFO:root:adding force harmonic_bonds 0
# INFO:root:adding force angle 1
# INFO:root:adding force polynomial_repulsive 2
# INFO:root:adding force three_way_attraction 3
# INFO:root:adding force remover 4
# INFO:root:Particles loaded. Potential energy is 126.191819
# INFO:root:before minimization eK=1.572402133345948, eP=126.19181256189901, time=0.0 ps
# INFO:root:Particles loaded. Potential energy is 0.283120
# INFO:root:after minimization eK=1.572402133345948, eP=-0.509070549612843, time=0.0 ps
# INFO:root:block    0 pos[1]=[-4.3 0.4 -2.7] dr=0.01 t=0.0ps kin=1.85 pot=0.05 Rg=11.755 SPS=353 dt=21.8fs dx=6.60pm
# INFO:root:block    1 pos[1]=[-3.9 -0.1 -1.4] dr=4.47 t=58.3ps kin=1.65 pot=1.45 Rg=11.479 SPS=1835 dt=30.0fs dx=8.61pm
# INFO:root:block    2 pos[1]=[-4.2 -0.4 0.0] dr=3.29 t=113.0ps kin=1.96 pot=1.41 Rg=11.058 SPS=2197 dt=26.3fs dx=8.23pm
# INFO:root:block    3 pos[1]=[-4.3 -1.5 -0.5] dr=3.82 t=167.3ps kin=2.11 pot=1.55 Rg=10.292 SPS=2717 dt=27.8fs dx=9.00pm
# INFO:root:block    4 pos[1]=[-5.7 1.3 -0.9] dr=4.10 t=222.4ps kin=1.90 pot=1.46 Rg=9.477 SPS=2452 dt=25.4fs dx=7.84pm
# INFO:root:block    5 pos[1]=[-3.8 2.8 1.4] dr=3.37 t=277.4ps kin=1.96 pot=1.52 Rg=9.564 SPS=2637 dt=25.9fs dx=8.09pm
# INFO:root:block    6 pos[1]=[0.4 1.1 1.6] dr=3.96 t=334.4ps kin=1.72 pot=1.39 Rg=10.255 SPS=2779 dt=28.4fs dx=8.33pm
# INFO:root:block    7 pos[1]=[0.1 2.8 1.7] dr=4.07 t=391.2ps kin=1.81 pot=1.42 Rg=10.518 SPS=2759 dt=30.1fs dx=9.05pm
# INFO:root:block    8 pos[1]=[-2.6 1.6 2.7] dr=3.66 t=446.6ps kin=1.91 pot=1.52 Rg=10.057 SPS=2685 dt=26.1fs dx=8.07pm
# INFO:root:block    9 pos[1]=[2.8 1.8 2.9] dr=4.38 t=502.0ps kin=1.83 pot=1.30 Rg=9.865 SPS=2754 dt=30.1fs dx=9.09pm
# INFO:root:block   10 pos[1]=[3.4 0.4 0.8] dr=3.56 t=557.1ps kin=1.95 pot=1.33 Rg=10.857 SPS=2672 dt=30.4fs dx=9.47pm
# INFO:root:block   11 pos[1]=[2.9 0.5 2.6] dr=3.98 t=611.2ps kin=2.01 pot=1.61 Rg=10.918 SPS=2357 dt=31.5fs dx=9.97pm
# INFO:root:block   12 pos[1]=[-3.4 -0.0 2.4] dr=3.81 t=666.2ps kin=2.09 pot=1.45 Rg=10.487 SPS=2744 dt=30.3fs dx=9.80pm
# INFO:root:block   13 pos[1]=[-0.0 -2.1 -2.3] dr=4.32 t=721.4ps kin=1.93 pot=1.80 Rg=9.876 SPS=2614 dt=27.7fs dx=8.59pm
# INFO:root:block   14 pos[1]=[2.1 2.9 0.9] dr=4.13 t=776.2ps kin=2.22 pot=1.52 Rg=9.581 SPS=2691 dt=29.4fs dx=9.78pm
# INFO:root:block   15 pos[1]=[1.1 -0.5 1.3] dr=3.51 t=830.1ps kin=1.90 pot=1.67 Rg=8.751 SPS=2662 dt=27.0fs dx=8.31pm
# INFO:root:block   16 pos[1]=[3.5 -1.3 0.2] dr=2.75 t=885.5ps kin=2.01 pot=1.45 Rg=8.317 SPS=2529 dt=25.2fs dx=7.99pm
# INFO:root:block   17 pos[1]=[1.0 -1.5 -1.5] dr=3.43 t=940.5ps kin=2.03 pot=1.62 Rg=8.032 SPS=2274 dt=26.5fs dx=8.46pm
# INFO:root:block   18 pos[1]=[-5.0 2.8 -1.8] dr=3.52 t=994.8ps kin=1.93 pot=1.55 Rg=7.458 SPS=2041 dt=27.8fs dx=8.63pm
# INFO:root:block   19 pos[1]=[-5.7 0.7 0.3] dr=3.88 t=1050.7ps kin=2.03 pot=1.42 Rg=6.714 SPS=2526 dt=29.6fs dx=9.43pm
# INFO:root:block   20 pos[1]=[-3.9 -0.5 1.1] dr=4.07 t=1106.8ps kin=1.97 pot=1.43 Rg=6.576 SPS=2607 dt=29.0fs dx=9.11pm
# INFO:root:block   21 pos[1]=[-6.7 1.8 -1.0] dr=4.16 t=1163.8ps kin=2.18 pot=1.21 Rg=7.526 SPS=2741 dt=26.5fs dx=8.74pm
# INFO:root:block   22 pos[1]=[-1.1 0.7 -2.6] dr=3.55 t=1219.1ps kin=1.80 pot=1.34 Rg=8.004 SPS=2483 dt=25.9fs dx=7.75pm
# INFO:root:block   23 pos[1]=[1.4 2.4 -0.1] dr=3.74 t=1274.1ps kin=2.01 pot=1.58 Rg=7.290 SPS=2727 dt=26.8fs dx=8.47pm
# INFO:root:block   24 pos[1]=[-2.0 -0.4 3.1] dr=3.66 t=1329.1ps kin=1.95 pot=1.38 Rg=7.358 SPS=2777 dt=28.3fs dx=8.83pm
# INFO:root:block   25 pos[1]=[-0.5 -4.3 2.4] dr=3.35 t=1386.1ps kin=1.70 pot=1.54 Rg=7.700 SPS=2730 dt=28.6fs dx=8.33pm
# INFO:root:block   26 pos[1]=[3.2 0.9 3.6] dr=3.58 t=1440.7ps kin=1.93 pot=1.60 Rg=7.408 SPS=2512 dt=27.1fs dx=8.41pm
# INFO:root:block   27 pos[1]=[-1.8 1.4 3.7] dr=3.22 t=1495.6ps kin=1.99 pot=1.45 Rg=7.973 SPS=2745 dt=25.9fs dx=8.14pm
# INFO:root:block   28 pos[1]=[-2.0 0.0 1.7] dr=3.30 t=1551.3ps kin=2.20 pot=1.42 Rg=7.363 SPS=2874 dt=26.4fs dx=8.75pm
# INFO:root:block   29 pos[1]=[1.5 -3.2 3.1] dr=3.33 t=1605.8ps kin=2.11 pot=1.51 Rg=7.129 SPS=2800 dt=26.7fs dx=8.67pm
# INFO:root:block   30 pos[1]=[1.8 4.7 -0.5] dr=3.55 t=1660.1ps kin=2.04 pot=1.75 Rg=7.554 SPS=2491 dt=26.7fs dx=8.51pm
# INFO:root:block   31 pos[1]=[3.5 2.9 -0.8] dr=3.08 t=1715.2ps kin=2.03 pot=1.50 Rg=7.485 SPS=2776 dt=27.1fs dx=8.62pm
# INFO:root:block   32 pos[1]=[2.2 1.7 0.8] dr=3.48 t=1771.1ps kin=1.86 pot=1.27 Rg=8.062 SPS=2632 dt=28.3fs dx=8.63pm
# INFO:root:block   33 pos[1]=[-5.1 3.7 0.1] dr=3.29 t=1827.7ps kin=1.66 pot=1.58 Rg=8.772 SPS=2025 dt=28.4fs dx=8.16pm
# INFO:root:block   34 pos[1]=[-2.7 0.4 -1.2] dr=3.74 t=1883.5ps kin=2.25 pot=1.44 Rg=9.015 SPS=2751 dt=29.7fs dx=9.94pm
# INFO:root:block   35 pos[1]=[-4.6 -0.2 2.1] dr=3.35 t=1938.8ps kin=1.88 pot=1.29 Rg=9.991 SPS=2166 dt=28.2fs dx=8.64pm
# INFO:root:block   36 pos[1]=[-0.6 5.6 1.6] dr=3.50 t=1993.7ps kin=1.97 pot=1.40 Rg=9.686 SPS=2295 dt=26.1fs dx=8.20pm
# INFO:root:block   37 pos[1]=[-2.5 3.9 4.2] dr=3.55 t=2048.6ps kin=1.90 pot=1.44 Rg=9.738 SPS=2770 dt=27.0fs dx=8.30pm
# INFO:root:block   38 pos[1]=[0.7 5.9 0.5] dr=3.77 t=2104.0ps kin=2.19 pot=1.30 Rg=10.204 SPS=2756 dt=31.4fs dx=10.37pm
# INFO:root:block   39 pos[1]=[-0.1 5.5 -0.2] dr=3.47 t=2158.8ps kin=1.96 pot=1.27 Rg=10.103 SPS=2508 dt=29.3fs dx=9.17pm
# INFO:root:block   40 pos[1]=[1.2 5.2 0.6] dr=3.84 t=2214.1ps kin=2.04 pot=1.33 Rg=9.226 SPS=2749 dt=26.8fs dx=8.55pm
# INFO:root:block   41 pos[1]=[3.0 1.5 -1.3] dr=4.13 t=2269.7ps kin=1.97 pot=1.41 Rg=8.828 SPS=2761 dt=27.4fs dx=8.58pm
# INFO:root:block   42 pos[1]=[1.4 -2.3 1.2] dr=3.78 t=2325.5ps kin=1.60 pot=1.57 Rg=7.352 SPS=2739 dt=29.0fs dx=8.18pm
# INFO:root:block   43 pos[1]=[2.3 0.0 -1.2] dr=3.23 t=2381.1ps kin=1.87 pot=1.63 Rg=7.399 SPS=2435 dt=26.0fs dx=7.93pm
# INFO:root:block   44 pos[1]=[4.1 0.3 -2.3] dr=3.20 t=2435.9ps kin=1.87 pot=1.54 Rg=7.401 SPS=2772 dt=27.4fs dx=8.36pm
# INFO:root:block   45 pos[1]=[2.5 -0.6 -2.2] dr=3.51 t=2491.2ps kin=1.94 pot=1.67 Rg=7.869 SPS=2754 dt=26.8fs dx=8.35pm
# INFO:root:block   46 pos[1]=[0.2 -2.1 -3.6] dr=3.79 t=2547.1ps kin=1.77 pot=1.51 Rg=8.688 SPS=2712 dt=26.5fs dx=7.86pm
# INFO:root:block   47 pos[1]=[1.2 -0.5 -2.5] dr=3.32 t=2601.5ps kin=1.69 pot=1.68 Rg=9.445 SPS=2723 dt=29.4fs dx=8.55pm
# INFO:root:block   48 pos[1]=[1.1 -0.2 -2.4] dr=3.88 t=2657.8ps kin=1.76 pot=1.53 Rg=9.865 SPS=2749 dt=30.0fs dx=8.90pm
# INFO:root:block   49 pos[1]=[2.7 1.8 -1.4] dr=3.27 t=2713.1ps kin=2.07 pot=1.40 Rg=9.581 SPS=2775 dt=26.0fs dx=8.37pm
# INFO:root:block   50 pos[1]=[0.7 3.2 -2.0] dr=3.72 t=2769.9ps kin=2.06 pot=1.32 Rg=8.911 SPS=2672 dt=29.1fs dx=9.32pm
# INFO:root:block   51 pos[1]=[1.4 -1.4 -3.8] dr=3.93 t=2826.8ps kin=1.92 pot=1.56 Rg=8.782 SPS=2754 dt=26.4fs dx=8.19pm
# INFO:root:block   52 pos[1]=[2.0 0.1 -4.3] dr=2.77 t=2882.2ps kin=1.93 pot=1.62 Rg=9.057 SPS=2744 dt=26.8fs dx=8.34pm
# INFO:root:block   53 pos[1]=[-1.4 2.3 -1.8] dr=2.56 t=2937.7ps kin=1.85 pot=1.60 Rg=8.921 SPS=2797 dt=28.1fs dx=8.55pm
# INFO:root:block   54 pos[1]=[1.7 1.7 -3.9] dr=4.08 t=2993.4ps kin=1.95 pot=1.58 Rg=9.121 SPS=2713 dt=28.5fs dx=8.87pm
# INFO:root:block   55 pos[1]=[-0.2 3.0 1.2] dr=4.09 t=3047.4ps kin=1.90 pot=1.95 Rg=9.072 SPS=2789 dt=25.8fs dx=7.94pm
# INFO:root:block   56 pos[1]=[-1.4 -2.5 -0.7] dr=3.52 t=3100.9ps kin=2.09 pot=1.65 Rg=8.711 SPS=2612 dt=27.2fs dx=8.78pm
# INFO:root:block   57 pos[1]=[1.6 0.4 -3.8] dr=3.45 t=3156.6ps kin=1.93 pot=1.56 Rg=8.317 SPS=2733 dt=30.2fs dx=9.38pm
# INFO:root:block   58 pos[1]=[-1.9 1.9 -5.4] dr=4.11 t=3213.9ps kin=2.06 pot=1.59 Rg=7.720 SPS=1933 dt=25.6fs dx=8.20pm
# INFO:root:block   59 pos[1]=[-3.8 4.2 -4.7] dr=4.05 t=3268.9ps kin=1.77 pot=1.85 Rg=7.847 SPS=1849 dt=25.3fs dx=7.54pm
# INFO:root:block   60 pos[1]=[-3.8 8.8 -1.8] dr=4.10 t=3324.1ps kin=1.90 pot=1.65 Rg=8.038 SPS=2346 dt=27.6fs dx=8.48pm
# INFO:root:block   61 pos[1]=[-0.9 9.4 -7.5] dr=3.61 t=3379.9ps kin=1.99 pot=1.46 Rg=8.517 SPS=2371 dt=26.5fs dx=8.35pm
# INFO:root:block   62 pos[1]=[-0.5 5.2 -3.8] dr=3.67 t=3435.4ps kin=1.84 pot=1.83 Rg=8.792 SPS=2354 dt=27.4fs dx=8.29pm
# INFO:root:block   63 pos[1]=[-1.6 8.4 -7.3] dr=3.93 t=3490.3ps kin=2.21 pot=1.91 Rg=9.615 SPS=2903 dt=27.7fs dx=9.18pm
# INFO:root:block   64 pos[1]=[-0.3 4.9 -8.9] dr=3.77 t=3545.8ps kin=1.88 pot=1.77 Rg=10.409 SPS=2017 dt=25.9fs dx=7.94pm
# INFO:root:block   65 pos[1]=[1.9 5.2 -8.8] dr=3.71 t=3600.7ps kin=2.21 pot=1.70 Rg=11.276 SPS=2672 dt=26.4fs dx=8.75pm
# INFO:root:block   66 pos[1]=[-1.8 5.2 -8.2] dr=3.64 t=3655.5ps kin=2.09 pot=1.79 Rg=12.123 SPS=2749 dt=26.1fs dx=8.42pm
# INFO:root:block   67 pos[1]=[-3.4 7.0 -8.3] dr=4.74 t=3709.8ps kin=2.18 pot=1.89 Rg=12.587 SPS=2901 dt=26.8fs dx=8.85pm
# INFO:root:block   68 pos[1]=[-5.0 10.7 -11.7] dr=4.05 t=3763.2ps kin=2.32 pot=1.74 Rg=13.325 SPS=2875 dt=26.2fs dx=8.90pm
# INFO:root:block   69 pos[1]=[0.5 11.3 -12.8] dr=3.11 t=3815.5ps kin=2.38 pot=1.85 Rg=13.427 SPS=2875 dt=24.9fs dx=8.60pm
# INFO:root:block   70 pos[1]=[-0.2 6.5 -11.4] dr=3.49 t=3869.2ps kin=2.10 pot=1.67 Rg=12.796 SPS=2889 dt=30.5fs dx=9.85pm
# INFO:root:block   71 pos[1]=[0.9 6.2 -11.1] dr=4.07 t=3924.4ps kin=2.17 pot=1.74 Rg=12.070 SPS=2672 dt=26.2fs dx=8.63pm
# INFO:root:block   72 pos[1]=[3.1 4.5 -12.4] dr=4.04 t=3980.2ps kin=1.92 pot=1.83 Rg=11.918 SPS=2888 dt=26.9fs dx=8.32pm
# INFO:root:block   73 pos[1]=[3.4 2.1 -17.8] dr=3.29 t=4035.5ps kin=2.21 pot=2.01 Rg=11.858 SPS=2865 dt=26.8fs dx=8.90pm
# INFO:root:block   74 pos[1]=[4.2 1.8 -16.1] dr=4.40 t=4088.9ps kin=2.20 pot=1.76 Rg=12.028 SPS=2684 dt=25.8fs dx=8.54pm
# INFO:root:block   75 pos[1]=[5.2 2.4 -13.9] dr=3.85 t=4142.7ps kin=2.20 pot=1.91 Rg=12.337 SPS=2905 dt=26.1fs dx=8.64pm
# INFO:root:block   76 pos[1]=[5.9 0.2 -12.6] dr=3.93 t=4195.5ps kin=2.20 pot=1.65 Rg=11.636 SPS=2558 dt=26.1fs dx=8.65pm
# INFO:root:block   77 pos[1]=[6.6 0.7 -5.8] dr=4.77 t=4250.7ps kin=2.00 pot=1.60 Rg=10.430 SPS=2903 dt=27.9fs dx=8.82pm
# INFO:root:block   78 pos[1]=[4.7 1.6 -4.2] dr=4.28 t=4306.8ps kin=2.11 pot=1.58 Rg=9.995 SPS=2836 dt=28.1fs dx=9.13pm
# INFO:root:block   79 pos[1]=[6.1 -0.5 -3.5] dr=4.15 t=4361.7ps kin=2.14 pot=1.63 Rg=10.806 SPS=2852 dt=27.4fs dx=8.96pm
# INFO:root:block   80 pos[1]=[5.3 -3.9 -4.0] dr=4.19 t=4417.0ps kin=2.11 pot=1.74 Rg=11.300 SPS=2888 dt=30.4fs dx=9.86pm
# INFO:root:block   81 pos[1]=[1.4 -5.3 -6.2] dr=4.27 t=4472.1ps kin=2.40 pot=1.69 Rg=11.683 SPS=1945 dt=26.3fs dx=9.11pm
# INFO:root:block   82 pos[1]=[-4.2 1.7 -4.2] dr=4.37 t=4526.1ps kin=2.18 pot=1.74 Rg=12.242 SPS=2592 dt=28.9fs dx=9.52pm
# INFO:root:block   83 pos[1]=[-4.6 -1.5 -2.8] dr=3.90 t=4581.0ps kin=2.08 pot=1.58 Rg=12.669 SPS=2926 dt=26.9fs dx=8.67pm
# INFO:root:block   84 pos[1]=[-4.1 -5.0 -8.2] dr=3.70 t=4635.5ps kin=1.75 pot=1.83 Rg=13.757 SPS=2885 dt=26.3fs dx=7.77pm
# INFO:root:block   85 pos[1]=[-8.1 -4.8 -5.7] dr=3.78 t=4690.9ps kin=1.84 pot=1.91 Rg=13.857 SPS=2780 dt=27.5fs dx=8.34pm
# INFO:root:block   86 pos[1]=[-4.7 -6.4 -9.9] dr=4.24 t=4744.2ps kin=2.08 pot=1.77 Rg=14.519 SPS=2531 dt=25.0fs dx=8.07pm
# INFO:root:block   87 pos[1]=[0.3 -3.2 -9.6] dr=4.22 t=4797.8ps kin=2.16 pot=1.63 Rg=15.483 SPS=2894 dt=25.4fs dx=8.36pm
# INFO:root:block   88 pos[1]=[-6.0 0.7 -12.1] dr=4.56 t=4853.2ps kin=1.93 pot=1.58 Rg=15.948 SPS=2867 dt=28.6fs dx=8.87pm
# INFO:root:block   89 pos[1]=[-5.0 -0.4 -9.8] dr=4.14 t=4908.4ps kin=2.02 pot=1.55 Rg=16.430 SPS=2897 dt=28.1fs dx=8.90pm
# INFO:root:block   90 pos[1]=[-9.3 -2.8 -5.7] dr=4.34 t=4964.2ps kin=2.07 pot=1.59 Rg=16.601 SPS=2597 dt=26.2fs dx=8.43pm
# INFO:root:block   91 pos[1]=[-11.8 -3.1 -5.5] dr=4.39 t=5019.0ps kin=1.88 pot=1.84 Rg=17.095 SPS=2884 dt=28.3fs dx=8.66pm
# INFO:root:block   92 pos[1]=[-8.1 -0.5 -6.5] dr=4.15 t=5073.1ps kin=2.06 pot=2.16 Rg=17.978 SPS=2874 dt=26.3fs dx=8.44pm
# INFO:root:block   93 pos[1]=[-5.8 -2.7 -8.2] dr=3.74 t=5125.7ps kin=2.24 pot=1.77 Rg=18.267 SPS=2722 dt=28.3fs dx=9.46pm
# INFO:root:block   94 pos[1]=[-7.2 -4.8 -9.8] dr=4.30 t=5180.0ps kin=2.04 pot=1.95 Rg=18.992 SPS=2909 dt=26.8fs dx=8.57pm
# INFO:root:block   95 pos[1]=[-15.4 -1.9 -8.7] dr=4.08 t=5234.1ps kin=2.14 pot=1.66 Rg=19.513 SPS=2908 dt=27.4fs dx=8.95pm
# INFO:root:block   96 pos[1]=[-12.9 0.1 -3.4] dr=3.46 t=5289.4ps kin=1.87 pot=1.63 Rg=18.994 SPS=2775 dt=25.7fs dx=7.84pm
# INFO:root:block   97 pos[1]=[-13.1 -4.4 -4.1] dr=3.67 t=5344.7ps kin=2.04 pot=1.86 Rg=18.200 SPS=2909 dt=29.4fs dx=9.39pm
# INFO:root:block   98 pos[1]=[-14.7 -6.5 -6.4] dr=4.52 t=5399.4ps kin=2.19 pot=1.85 Rg=17.940 SPS=2929 dt=27.1fs dx=8.96pm
# INFO:root:block   99 pos[1]=[-15.2 -4.7 -5.8] dr=3.86 t=5454.2ps kin=2.12 pot=1.73 Rg=18.684 SPS=2908 dt=31.3fs dx=10.19pm
#  Statistics: number of particles: 120
#
# Statistics for particle position
#      mean position is:  [ 0.00299293 -0.00573332  0.0013068 ]   Rg =  18.684143
#      median bond size is  1.0212589221999708
#      three shortest/longest (<10)/ bonds are  [0.977577   0.97775358 0.97882581]    [1.11039952 1.11238965 1.14425208]
# longest 10 bonds are [ 1.08108007  1.08667219  1.08715554  1.09565889  1.09694471  1.11039952
#   1.11238965  1.14425208 24.44112877 30.15936364]
#      95 percentile of distance to center is:    22.5715449015009
#      density of closest 95% monomers is:    0.002366641012681677
#      density of the 5% closest to CoM monomers is:    0.0007870458709053448
#      min/median/mean/max coordinates are:
#      x: -18.79, -2.41, 0.00, 22.51
#      y: -12.49, -4.73, -0.01, 17.20
#      z: -12.67, -2.92, 0.00, 15.29
#
# Statistics for velocities:
#      mean kinetic energy is:  2.1809106408964465 should be: 1.5
#      fastest particles are (in kT):  [ 5.4890064   6.59648949  7.8455139   9.39505211 10.9931478 ]
#
# Statistics for the system:
#      Forces are:  ['harmonic_bonds', 'angle', 'polynomial_repulsive', 'three_way_attraction', 'remover']
#
# Potential Energy Ep =  1.7330649224943993

# %%
twf = three_way_force
twf.getTypeFilter(2)
# Out:
# (4,)

# %%
# data = sim.get_data() 
# pickle.dump(data, open("scrunched.pkl", "wb"))  # save the data to a file

# %%
dh = np.array(all_dh)
np.mean(dh, axis=0)  # mean dihedral angles
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/py313/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:3860: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/homebrew/Caskroom/miniconda/base/envs/py313/lib/python3.13/site-packages/numpy/_core/_methods.py:145: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# np.float64(nan)

# %%
import matplotlib.pyplot as plt
plt.figure() 
plt.scatter(dh[:, 0], dh[:, 2], s=1,  cmap="viridis")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure()
# ----> 3 plt.scatter(dh[:, 0], dh[:, 2], s=1,  cmap="viridis")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
